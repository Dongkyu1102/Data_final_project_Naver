# %% [markdown]
# <a href="https://colab.research.google.com/github/Dongkyu1102/Data_final_project_Naver/blob/main/%EC%87%BC%ED%95%91%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re
from tqdm.auto import tqdm

DATA_PATH = "/content/drive/MyDrive/2조_누구냐, 넌!/04. 기타자료/Naver_shopping_크롤링/수집자료/"

# %%
brand = '비어멕'
df = pd.read_csv(f"{DATA_PATH}{brand}.csv")
df['brand']=f'{brand}'
df
# Out:
#                                                 content  score       date  \
# 0     순하게괜찮은거같이요 꾸준히 써보고 좋으면계속 써볼생각입니다 제발머리좀 덜빠졌음하네요...      5  23.09.02.
# 1     머리카락이 너무 많이 빠져 구매해봤어요 오늘 첨 써봤는데 거품은 풍부했고 세정력은 ...      4  23.08.18.
# 2     3개왔는게 그중 1개만 찍었어요. 우선 아직 사용해보지는 못해서, 사용해보고 한달 ...      5  23.08.28.
# 3     먼저 빠른 배송에 만족합니다^^ 받자마자 퇴근후 사용해 봤는데 향도 은은하고 조금만...      5  23.07.11.
# 4     거품도 부드럽고 헹굼시 뻑뻑함이 덜하네요 탈모 방지는 좀더 써봐야 알거 같고 대체로...      4  23.08.20.
# ...                                                 ...    ...        ...
# 5775                                     배달에서 사용감이 좋아요.      5  17.03.20.
# 5776                                             만족만족만족      5  17.04.16.
# 5777                                      잘 받았습니다  ....      5  17.03.15.
# 5778  구매 제품을 사용을 해보니~~ 며칠을 사용을 해보니 두피가 상쾌하며 그 효과도 기대...      4  17.03.20.
# 5779                                         흐즞ㄷㅈㄷㅈㄷㅈㄷㅈ      3  17.03.29.
#
#                           option                                   satis_list  \
# 0        조합상품: 5. 탈모샴푸1개+트리트먼트1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 1       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# 2     조합상품: 6. 여행용샴푸(100ml) X 3개  ['세정력_보통이에요', '두피자극_보통이에요', '탈모케어_잘 모르겠어요']
# 3       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 4       조합상품: 3. 탈모샴푸 500ml X 2개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# ...                          ...                                          ...
# 5775                 상품종류: 트리트먼트                                         ['']
# 5776                    상품종류: 샴푸                                         ['']
# 5777                         NaN                                         ['']
# 5778                 상품종류: 트리트먼트                                         ['']
# 5779                 상품종류: 트리트먼트                                         ['']
#
#      brand
# 0      비어멕
# 1      비어멕
# 2      비어멕
# 3      비어멕
# 4      비어멕
# ...    ...
# 5775   비어멕
# 5776   비어멕
# 5777   비어멕
# 5778   비어멕
# 5779   비어멕
#
# [5780 rows x 6 columns]

# %%
df[df["score"] == 5]
# Out:
#                                                 content  score       date  \
# 0     순하게괜찮은거같이요 꾸준히 써보고 좋으면계속 써볼생각입니다 제발머리좀 덜빠졌음하네요...      5  23.09.02.
# 2     3개왔는게 그중 1개만 찍었어요. 우선 아직 사용해보지는 못해서, 사용해보고 한달 ...      5  23.08.28.
# 3     먼저 빠른 배송에 만족합니다^^ 받자마자 퇴근후 사용해 봤는데 향도 은은하고 조금만...      5  23.07.11.
# 5                               한달사용기재구매정말 좋아요 몇년째쓰고있어요      5  23.09.05.
# 7     한달사용기믿고 쓰는 샴푸입니다 힘없이 쳐지는 모발.가는 모발에 적극 추천합니다 머리...      5  23.08.08.
# ...                                                 ...    ...        ...
# 5772                                             잘받았습니다      5  17.03.28.
# 5774                                             만독만족만족      5  17.04.16.
# 5775                                     배달에서 사용감이 좋아요.      5  17.03.20.
# 5776                                             만족만족만족      5  17.04.16.
# 5777                                      잘 받았습니다  ....      5  17.03.15.
#
#                           option                                   satis_list  \
# 0        조합상품: 5. 탈모샴푸1개+트리트먼트1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 2     조합상품: 6. 여행용샴푸(100ml) X 3개  ['세정력_보통이에요', '두피자극_보통이에요', '탈모케어_잘 모르겠어요']
# 3       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 5      조합상품: 7. 탈모샴푸 1개+여행용샴푸 3개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 7       조합상품: 3. 탈모샴푸 500ml X 2개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# ...                          ...                                          ...
# 5772                    상품종류: 샴푸                                         ['']
# 5774                 상품종류: 트리트먼트                                         ['']
# 5775                 상품종류: 트리트먼트                                         ['']
# 5776                    상품종류: 샴푸                                         ['']
# 5777                         NaN                                         ['']
#
#      brand
# 0      비어멕
# 2      비어멕
# 3      비어멕
# 5      비어멕
# 7      비어멕
# ...    ...
# 5772   비어멕
# 5774   비어멕
# 5775   비어멕
# 5776   비어멕
# 5777   비어멕
#
# [4444 rows x 6 columns]

# %%
df[df["score"] == 5].shape[0], df[df["score"] == 4].shape[0], df[df["score"] == 3].shape[0], df[df["score"] == 2].shape[0], df[df["score"] == 1].shape[0]
# Out:
# (4444, 904, 397, 30, 5)

# %%
df["한달사용기"] = 0
df["재구매"] = 0
df
# Out:
#                                                 content  score       date  \
# 0     순하게괜찮은거같이요 꾸준히 써보고 좋으면계속 써볼생각입니다 제발머리좀 덜빠졌음하네요...      5  23.09.02.
# 1     머리카락이 너무 많이 빠져 구매해봤어요 오늘 첨 써봤는데 거품은 풍부했고 세정력은 ...      4  23.08.18.
# 2     3개왔는게 그중 1개만 찍었어요. 우선 아직 사용해보지는 못해서, 사용해보고 한달 ...      5  23.08.28.
# 3     먼저 빠른 배송에 만족합니다^^ 받자마자 퇴근후 사용해 봤는데 향도 은은하고 조금만...      5  23.07.11.
# 4     거품도 부드럽고 헹굼시 뻑뻑함이 덜하네요 탈모 방지는 좀더 써봐야 알거 같고 대체로...      4  23.08.20.
# ...                                                 ...    ...        ...
# 5775                                     배달에서 사용감이 좋아요.      5  17.03.20.
# 5776                                             만족만족만족      5  17.04.16.
# 5777                                      잘 받았습니다  ....      5  17.03.15.
# 5778  구매 제품을 사용을 해보니~~ 며칠을 사용을 해보니 두피가 상쾌하며 그 효과도 기대...      4  17.03.20.
# 5779                                         흐즞ㄷㅈㄷㅈㄷㅈㄷㅈ      3  17.03.29.
#
#                           option                                   satis_list  \
# 0        조합상품: 5. 탈모샴푸1개+트리트먼트1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 1       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# 2     조합상품: 6. 여행용샴푸(100ml) X 3개  ['세정력_보통이에요', '두피자극_보통이에요', '탈모케어_잘 모르겠어요']
# 3       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 4       조합상품: 3. 탈모샴푸 500ml X 2개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# ...                          ...                                          ...
# 5775                 상품종류: 트리트먼트                                         ['']
# 5776                    상품종류: 샴푸                                         ['']
# 5777                         NaN                                         ['']
# 5778                 상품종류: 트리트먼트                                         ['']
# 5779                 상품종류: 트리트먼트                                         ['']
#
#      brand  한달사용기  재구매
# 0      비어멕      0    0
# 1      비어멕      0    0
# 2      비어멕      0    0
# 3      비어멕      0    0
# 4      비어멕      0    0
# ...    ...    ...  ...
# 5775   비어멕      0    0
# 5776   비어멕      0    0
# 5777   비어멕      0    0
# 5778   비어멕      0    0
# 5779   비어멕      0    0
#
# [5780 rows x 8 columns]

# %%
df.loc[df["content"].str.startswith("한달사용기"), "한달사용기"] =1

# %%
df.loc[df["content"].str.startswith("한달사용기")]
# Out:
#                                                 content  score       date  \
# 5                               한달사용기재구매정말 좋아요 몇년째쓰고있어요      5  23.09.05.
# 7     한달사용기믿고 쓰는 샴푸입니다 힘없이 쳐지는 모발.가는 모발에 적극 추천합니다 머리...      5  23.08.08.
# 12                               한달사용기머릿결이 좋아지네요 자극도 없고      5  23.08.22.
# 14                      한달사용기재구매항상 쓰고있는데 시원하고 말끔해서 좋습니다      3  23.08.21.
# 17                           한달사용기샴푸도 순하고 머리를 개운하게 해주네요      5  23.08.22.
# ...                                                 ...    ...        ...
# 4305                              한달사용기재구매용량이 좀작아서 아쉽네요      5  18.11.27.
# 4307                         한달사용기모발을 가늘게 만드는 성분이 다량 함유      1  18.11.27.
# 4314                                 한달사용기1년가까이 사용 중입니다      4  18.11.29.
# 4315                 한달사용기두피가 빨개지는것때문에 샀는데 효과는 그닥 모르겠네요      3  18.11.22.
# 4318                  한달사용기머리 감을때마다 빠지는  머리카락수가 많이 줄었어요      5  18.11.21.
#
#                          option  \
# 5     조합상품: 7. 탈모샴푸 1개+여행용샴푸 3개
# 7      조합상품: 3. 탈모샴푸 500ml X 2개
# 12    조합상품: 4. 트리트먼트 500ml X 2개
# 14     조합상품: 3. 탈모샴푸 500ml X 2개
# 17     조합상품: 3. 탈모샴푸 500ml X 2개
# ...                         ...
# 4305               상품종류: 01. 샴푸
# 4307               상품종류: 01. 샴푸
# 4314               상품종류: 01. 샴푸
# 4315               상품종류: 01. 샴푸
# 4318               상품종류: 01. 샴푸
#
#                                              satis_list brand  한달사용기  재구매
# 5           ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']   비어멕      1    0
# 7           ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']   비어멕      1    0
# 12          ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']   비어멕      1    0
# 14    ['헤어_지성가려움', '세정력_보통이에요', '두피자극_보통이에요', '탈모케어_...   비어멕      1    0
# 17          ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']   비어멕      1    0
# ...                                                 ...   ...    ...  ...
# 4305                                      ['세정력_보통이에요']   비어멕      1    0
# 4307                                      ['세정력_보통이에요']   비어멕      1    0
# 4314                                      ['세정력_보통이에요']   비어멕      1    0
# 4315                                    ['세정력_아주 만족해요']   비어멕      1    0
# 4318                                    ['세정력_아주 만족해요']   비어멕      1    0
#
# [1014 rows x 8 columns]

# %%
df.loc[df["content"].str.startswith("한달사용기"), "한달사용기"] = 1
df.loc[df["content"].str.startswith("재구매"), "재구매"] = 1
df.loc[df["content"].str.startswith('한달사용기재구매'),'재구매'] = 1
df
# Out:
#                                                 content  score       date  \
# 0     순하게괜찮은거같이요 꾸준히 써보고 좋으면계속 써볼생각입니다 제발머리좀 덜빠졌음하네요...      5  23.09.02.
# 1     머리카락이 너무 많이 빠져 구매해봤어요 오늘 첨 써봤는데 거품은 풍부했고 세정력은 ...      4  23.08.18.
# 2     3개왔는게 그중 1개만 찍었어요. 우선 아직 사용해보지는 못해서, 사용해보고 한달 ...      5  23.08.28.
# 3     먼저 빠른 배송에 만족합니다^^ 받자마자 퇴근후 사용해 봤는데 향도 은은하고 조금만...      5  23.07.11.
# 4     거품도 부드럽고 헹굼시 뻑뻑함이 덜하네요 탈모 방지는 좀더 써봐야 알거 같고 대체로...      4  23.08.20.
# ...                                                 ...    ...        ...
# 5775                                     배달에서 사용감이 좋아요.      5  17.03.20.
# 5776                                             만족만족만족      5  17.04.16.
# 5777                                      잘 받았습니다  ....      5  17.03.15.
# 5778  구매 제품을 사용을 해보니~~ 며칠을 사용을 해보니 두피가 상쾌하며 그 효과도 기대...      4  17.03.20.
# 5779                                         흐즞ㄷㅈㄷㅈㄷㅈㄷㅈ      3  17.03.29.
#
#                           option                                   satis_list  \
# 0        조합상품: 5. 탈모샴푸1개+트리트먼트1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 1       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# 2     조합상품: 6. 여행용샴푸(100ml) X 3개  ['세정력_보통이에요', '두피자극_보통이에요', '탈모케어_잘 모르겠어요']
# 3       조합상품: 1. 탈모샴푸 500ml X 1개  ['두피자극_순해요', '탈모케어_아주 만족해요', '세정력_아주 만족해요']
# 4       조합상품: 3. 탈모샴푸 500ml X 2개  ['두피자극_순해요', '탈모케어_잘 모르겠어요', '세정력_아주 만족해요']
# ...                          ...                                          ...
# 5775                 상품종류: 트리트먼트                                         ['']
# 5776                    상품종류: 샴푸                                         ['']
# 5777                         NaN                                         ['']
# 5778                 상품종류: 트리트먼트                                         ['']
# 5779                 상품종류: 트리트먼트                                         ['']
#
#      brand  한달사용기  재구매
# 0      비어멕      0    0
# 1      비어멕      0    0
# 2      비어멕      0    0
# 3      비어멕      0    0
# 4      비어멕      0    0
# ...    ...    ...  ...
# 5775   비어멕      0    0
# 5776   비어멕      0    0
# 5777   비어멕      0    0
# 5778   비어멕      0    0
# 5779   비어멕      0    0
#
# [5780 rows x 8 columns]

# %%
df.loc[df["content"].str.startswith("BEST")]
# Out:
# Empty DataFrame
# Columns: [content, score, date, option, satis_list, brand, 한달사용기, 재구매]
# Index: []

# %%
df.loc[df["content"].str.startswith("BEST")].shape
# Out:
# (0, 8)

# %%
DATA_PATH_2 = "/content/drive/MyDrive/2조_누구냐, 넌!/04. 기타자료/Naver_shopping_크롤링/data/"

# %%
df.to_csv(f'{DATA_PATH_2}{brand}_전처리.csv', encoding='utf-8-sig')
